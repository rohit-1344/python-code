# %% [markdown]
# Matplotlib

# %%
     import matplotlib.pyplot as plt
     import numpy as np

     x=np.linspace(0,1,10)
     m=25
     c=250
     y=m*x + c
     plt.plot(x,y)
     plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(0,10,100)
y=4+3*np.sin(x)

fig, a=plt.subplot()
a=plot(x,y,linewidth=3.0)
a.set(xlim=(0, 8), xticks=np.arrange(1, 8),
      ylim=(0, 8),   yticks=np.arrange(1, 8))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-793a76248c0d> in <cell line: 7>()
#       5 y=4+3*np.sin(x)
#       6
# ----> 7 fig, a=plt.subplot()
#       8 a=plot(x,y,linewidth=3.0)
#       9 a.set(xlim=(0, 8), xticks=np.arrange(1, 8),
#
# TypeError: cannot unpack non-iterable Axes object

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,5,13,25,33,46]).reshape((-1,1))
y=np.array([3,6,9,12,15,18])
plt.scatter(x,y)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
SLR=LinearRegression()
SLR.fit(x,y)
pred=SLR.predict(x)
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,pred)
plt.plot(x,pred,color='green',marker='*')
print("MSE:",mse)
print("intercept",SLR.intercept_)
print("slope",SLR.coef_)
# Out:
# MSE: 0.5497173262387761
# intercept 3.93481875623545
# slope [0.32025274]

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

data = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data.xlsx')
x = data['x'].values.reshape(-1, 1)
y = data['y'].values

model = LinearRegression()
model.fit(x, y)

slope = model.coef_[0]
intercept = model.intercept_

plt.scatter(x, y)
plt.plot(x, model.predict(x), color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Linear Regression')
plt.show()

print("Slope:", slope)
print("Intercept:", intercept)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Slope: 0.8868462967878948
# Intercept: 1.2332094504911062
